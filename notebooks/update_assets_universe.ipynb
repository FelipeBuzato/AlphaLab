# %%
import pandas as pd
import psycopg2

# %%
assets_universe = pd.read_csv("../Database/data_ingestion/assets_universe.csv")
assets_universe
# Out:
#   ticker asset_type
# 0   AAPL     equity
# 1   TSLA     equity

# %%
assets_universe.loc[len(assets_universe)] = ['GOOGL', 'equity']
assets_universe
# Out:
#   ticker asset_type
# 0   AAPL     equity
# 1   TSLA     equity
# 2  GOOGL     equity

# %%
assets_universe.to_csv("../Database/data_ingestion/assets_universe.csv", index=False)
assets_universe = pd.read_csv("../Database/data_ingestion/assets_universe.csv")
assets_universe
# Out:
#   ticker asset_type
# 0   AAPL     equity
# 1   TSLA     equity
# 2  GOOGL     equity
